# %% [markdown]
#
# <h1 align='center'>  <font size = '6' color='red'> Applied Statistics  <font> </h1>
#
#
# <br>
# <center><h2> <center> <font color='green'> CHAPTER 2: The Importance of
# Data Visualization in
# Business Intelligence <font> </h2> </center>
# <br>
#
# ![logo.png](attachment:logo.png)
#
#
# <br>
# <!-- <center align="left"> Developed for the MSc Program in Data Science  </center> -->
#
# <center align="left"> Ala-too International University </center>
#
#   <center align="left">    <center align="left"><center align="left"> <font color='dark blue'><font style= 'bold' size='3' color='dark'>  Dr. Remudin Reshid MEKURIA <font> </center>

# %% [markdown]
# **Data visualization** is the process of interpreting data and presenting it in
# a pictorial or graphical format.

# %% [markdown]
# A <font color='red'> decision-maker </font> for any business wants to access highly visual business intelligence (BI) tools that can help to make the right decisions quickly.
# A BI dashboard can be a great way to compile several different data visualizations to provide an at-a-glance overview of business performance and areas for improvement.

# %% [markdown]
# **Data visualization helps people understand
# the significance of data by summarizing and presenting a huge amount of
# data in a simple and easy-to-understand format in order to communicate
# the information clearly and effectively.**

# %% [markdown]
# # <font color='red'> Why Is Data Visualization Important?</font>

# %% [markdown]
# Data visualization helps the business to achieve numerous goals.
# * Converting the business data into interactive graphs for dynamic interpretation to serve the business goals
# * Transforming data into visually appealing, interactive dashboards of various data sources to serve the business with the insights
# * Creating more attractive and informative dashboards of various graphical data representations
# * Making appropriate decisions by drilling into the data and finding the insights
# * Figuring out the patterns, trends, and correlations in the data being analyzed to determine where they must improve their operational processes and thereby grow their business
# * Giving a fuller picture of the data under analysis
# * Organizing and presenting massive data intuitively to present important findings from the data
# * Making better, quick, and informed decisions with data visualization

# %% [markdown]
# # <font color='red'> Why Do Modern Businesses Need Data Visualization?

# %% [markdown]
# With the huge volume of data collected about business activities using
# different means, business leaders need proper techniques to easily drill
# down into the data to see where they can improve operational processes
# and grow their business.

# %% [markdown]
# **Data visualization is needed by modern businesses for the following
# reasons:**

# %% [markdown]
# * Data visualization helps companies to analyze its different processes so the management can <font color='red'> focus on the areas for improvement to generate more revenue and improve productivity.<font>
# * It brings business intelligence to life.
# * It applies a creative approach to understanding the hidden information within the business data.
# * It provides <font color='red'> a better and faster way to identify patterns, trends, and correlation in the data sets that would remain undetected with just text.<font>
# * It identifies new business opportunities by predicting upcoming trends or sales volumes and the revenue they will generate.
# * It supplies managers with information they need to make more effective comparisons between data sets by plotting them on the same visualization.
# * It enables managers to understand the correlations between the operating conditions and the business performance.
# * It helps businesses to discover the gray areas of the business and make the right decisions for improvement.
# * Data visualization helps managers to <font color='red'>understand customers’ behaviors and interests and hence retains customers and market share.<font>

# %% [markdown]
# # <font color='red'> Introducing Data Visualization Techniques

# %% [markdown]
# **Data visualization** aims to understand data by extracting and graphing
# information to show patterns, spot trends, and identify outliers. There are
# two basic types of data visualization.
# * Exploration helps to extract information from the
# collected data.
# * Explanation demonstrates the extracted information.

# %% [markdown]
# In the following we will see variouse data visualization techniques using python.

# %%
pip list #this gives us the list of already available packages
# Out:
# Package                            Version
# ---------------------------------- -------------------
# Active-SQLAlchemy                  0.3.2
# alabaster                          0.7.12
# anaconda-client                    1.8.0
# anaconda-navigator                 2.0.4
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.6
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.3
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# bokeh                              2.3.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2021.5.30
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.1
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.10.3
# conda-build                        3.21.5
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# corner                             2.2.1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# dask                               2021.8.1
# debugpy                            1.4.1
# decorator                          5.0.9
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.6
# distributed                        2021.8.1
# docutils                           0.17.1
# emcee                              3.1.3
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              0.10.1
# Flask-Assets                       0.10
# Flask-Classy                       0.6.10
# Flask-KVSession                    0.6.1
# Flask-Login                        0.2.11
# Flask-ReCaptcha                    0.3
# Flask-S3                           0.1.7
# fonttools                          4.25.0
# fsspec                             2021.7.0
# future                             0.18.2
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           1.1.1
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# humanize                           0.5.1
# idna                               3.2
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.6.4
# iniconfig                          1.1.1
# install                            1.3.5
# intervaltree                       3.1.0
# iplot                              0.0.0
# ipykernel                          6.2.0
# ipython                            7.26.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.17.2
# jeepney                            0.7.1
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     7.0.1
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-server                     1.4.1
# jupyterlab                         3.1.7
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.7.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.0.1
# kiwisolver                         1.3.1
# latexify-py                        0.2.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         2.0.1
# matplotlib                         3.4.2
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.8.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.2
# nltk                               3.6.2
# nose                               1.3.7
# notebook                           6.4.3
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.21.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          21.0
# pandas                             1.3.1
# pandocfilters                      1.4.3
# parso                              0.7.0
# partd                              1.2.0
# passlib                            1.6.2
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.3.1
# pip                                22.3.1
# pkginfo                            1.7.1
# plotly                             5.13.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.1.1
# pyee                               7.0.4
# pyerfa                             2.0.0
# pyflakes                           2.2.0
# Pygments                           2.10.0
# pylint                             2.9.6
# Pylot                              0.0.1
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyMySQL                            0.6.1
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyppeteer                          0.2.2
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-slugify                     0.1.0
# pytz                               2021.1
# PyWavelets                         1.1.1
# pyxdg                              0.27
# PyYAML                             5.4.1
# pyzmq                              22.2.1
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.1.0
# QtPy                               1.10.0
# redis                              2.9.1
# regex                              2021.8.3
# requests                           2.26.0
# rope                               0.19.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.2
# scipy                              1.7.1
# seaborn                            0.11.2
# SecretStorage                      3.3.1
# Send2Trash                         1.5.0
# SES-Mailer                         0.13.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# simplekv                           0.14.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.0.2
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         0.9.8
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# tenacity                           8.1.0
# terminado                          0.9.4
# testpath                           0.5.0
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2020.10.1
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.1
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.10.0.0
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.3.6
# urllib3                            1.26.6
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webassets                          2.0
# webencodings                       0.5.1
# websockets                         8.1
# Werkzeug                           1.0.1
# wheel                              0.37.0
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.5.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### if you want to install a new package then you use pip install name_of_the_package for example:

# %%
pip install plotly #plotly is a python library which is an interactive, open-source plotting library that supports over 40 unique chart types covering a wide range of statistical, financial, geographic, scientific, and 3-dimensional use-cases.
# Out:
# Requirement already satisfied: plotly in /home/remudin/anaconda3/lib/python3.8/site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/remudin/anaconda3/lib/python3.8/site-packages (from plotly) (8.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### It's very common and useful to use matplotlib for **simple bar charts, line charts, and scatterplots**.

# %%
from matplotlib import  pyplot as plt

x = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
y = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

print(type(x))

# create a line chart, years on x-axis, gdp on y-axis

plt.plot(x,y, color="red", marker='*', linestyle='dashed')

# add a title

plt.xlabel("Years")

plt.ylabel("Billions of $")

# %mkdir ./img3 #this is for making directory for saving an image as follows:
#once the folder is created you need to comment this line
plt.savefig('img3/viz_gdp.png')

plt.show()
#plt.gca().clear()
# Out:
# <class 'list'>
# mkdir: cannot create directory ‘./img3’: File exists

# %%
ls img3
# Out:
# viz_gdp.png

# %%
pwd
# Out:
# '/home/remudin/Documents/Advanced_DAV'

# %%
ls
# Out:
# Advanced_DAV_Chapter_1.ipynb*               Advanced_DAV_Chapter_6.ipynb
# Advanced_DAV_Chapter_2.ipynb*               AppliedStatistics_Ch1.ipynb
# Advanced_DAV_Chapter_3.ipynb*               AS_Chapter_2.ipynb
# Advanced_DAV_Chapter_3-March4Version.ipynb  img2/
# Advanced_DAV_Chapter_4_2025.ipynb           img3/
# Advanced_DAV_Chapter_4.ipynb*               temp-plot.html
# Advanced_DAV_Chapter_5.ipynb*

# %%
ls img3/
# Out:
# viz_gdp.png

# %% [markdown]
# ###  <font color='red'> Bar Charts </font>
#
# A **bar chart** is a good choice when you want to show how some quantity varies among
# some ***discrete set of items***.
#
# For instance, the next figure shows how many Academy Awards were won by each of a variety of movies

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
#plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
print("length of the movies:", len(movies))
# Out:
# length of the movies: 5

# %% [markdown]
# It is as if you are joining these points on x-y plane in the form of bars!
#
# (0, 5)
# (1, 11)
# (2, 3)
# (3, 8)
# (4, 10)

# %%
plt.bar(range(len(movies)), num_oscars)

plt.title("My Favorite Movies")     # add a title

plt.ylabel("# of Academy Awards")   # label the y-axis

# label x-axis with movie names at bar centers

plt.xticks(range(len(movies)), movies)

plt.savefig('img2/viz_movies.png')
plt.show()

# %% [markdown]
# A bar chart can also be a good choice for plotting **histograms of bucketed numeric
# values**, in order to visually explore how the values are distributed, as in figure below

# %%
from collections import Counter

grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]#data we use

decile = lambda grade: grade // 10 * 10 ## Exercise: Learn how this works?

histogram = Counter(decile(grade) for grade in grades)

print(histogram)
print(histogram.keys())
print(histogram.values())
# Out:
# Counter({80: 4, 70: 3, 90: 2, 0: 2, 100: 1, 60: 1})
# dict_keys([80, 90, 70, 0, 100, 60])
# dict_values([4, 2, 3, 2, 1, 1])

# %%
#plt.bar([x + 4  for x in histogram.keys()], # shift each bar to the right by x+4
#plt.bar([x - 4 for x in histogram.keys()], # shift each bar to the left by x-4
plt.bar([x  for x in histogram.keys()], # no shift

        histogram.values(),# give each bar its correct height
        8) # give each bar a width of 8

plt.axis([-10, 110, 0, 5])
# x-axis from -10 to 110,
# y-axis from 0 to 5

plt.xticks([10 * i for i in range(11)])# x-axis labels at 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.savefig('img2/viz_grades2.png')
plt.show()

# %% [markdown]
# ### The third argument to **plt.bar** specifies the bar width.
#
# -**(Here we chose a width of 8 (which leaves a small gap between bars, since our buckets have width 10).)**
#
# -**And we shifted the bar left by 4, so that (for example) the “80” bar has its left and right sides at
# 76 and 84, and (hence) its center at 80.**
#
# -**The call to plt.axis indicates that we want the x-axis to range from -5 to 105 (so that
# the “0” and “100” bars are fully shown), and that the y-axis should range from 0 to 5.**
#
# -**And the call to plt.xticks puts x-axis labels at 0, 10, 20, ..., 100.**

# %%
from collections import Counter

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

# Bucket grades by decile, but put 100 in with the 90s ''some how forcing 100 also to be counted with the groups of 90's"
histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

# %%
print(histogram)
# Out:
# Counter({80: 4, 90: 3, 70: 3, 0: 2, 60: 1})

# %% [markdown]
# #### It printed how many numbers are there with in range of ten. For example there are 4 numbers between 80 and 90, 3 numbers between 90 and 100, etc

# %%
plt.bar([x + 5 for x in histogram.keys()],  # Shift bars right by 5
        histogram.values(),                 # Give each bar its correct height
        8,                                 # Give each bar a width of 8
        edgecolor=(0, 0, 0))                # Black edges for each bar

plt.axis([-10, 110, 0, 5])                  # x-axis from -10 to 110,
                                           # y-axis from 0 to 5

plt.xticks([10 * i for i in range(11)])    # x-axis labels at 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.savefig('img2/viz_grades1.png')
plt.show()

# %% [markdown]
# ### Example: How many times people have mensioned the word data science during the year 2017 and 2018

# %%
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)

plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

# if you don't do this, matplotlib will label the x-axis 0, 1
# and then add a +2.013e3 off in the corner (bad matplotlib!)

plt.ticklabel_format(useOffset=False)

# misleading y-axis only shows the part above 500
plt.axis([2016.5, 2018.5, 499, 506]) ##plt.axis contains both([x-axis range, y-axis range])
plt.title("Look at the 'Huge' Increase!")
plt.savefig('img2/viz_misleading_y_axis.png')
plt.show()

# %% [markdown]
# #### In the figure below, we use more-sensible axes, and it looks far less impressive:

# %%
plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")
plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 0, 550])
plt.title("Not So Huge Anymore")
plt.savefig('img2/viz_non_misleading_y_axis.png')
plt.show()

# %% [markdown]
# #### Thus the above figure is the same chart wich is not with a misleading y-axis

# %% [markdown]
# ###  <font color='red'> Scatterplots </font>

# %% [markdown]
# A **scatterplot** is the right choice for visualizing the **relationship between two paired**
# sets of data.
#
# For example, in the following figure illustrates the relationship between the number
# of friends your users have and the number of minutes they spend on the site every
# day:

# %%
friends = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

# label each point
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
        xy=(friend_count, minute_count), # Put the label with its point (x,y)
        xytext=(5, -5),                  # but slightly offset
        textcoords='offset points')
    

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.grid(True, color="gray")
plt.savefig('img2/viz_scatterplot.png')
plt.show()

# %% [markdown]
# #### A scatterplot of friends and time on the site is shown above.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
#%matplotlib inline #for static mode

# %%
# %matplotlib notebook #for interactive mode

# %%
plt.style.use('seaborn-white')
# Out:
# /tmp/ipykernel_4102/1193657973.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]

# %%
plt.scatter(X,Y)
plt.xlim(0,1000)
plt.ylim(0,100)
#scatter plot color
plt.scatter(X, Y, s=60, c='red', marker='^')

# %%
#scatter plot color
plt.scatter(X, Y, s=60, c='red', marker='^')
#change axes ranges
plt.xlim(0,1000)
plt.ylim(0,100)
#add title
plt.title('Relationship Between Temperature and Iced Coffee Sales')
#add x and y labels
plt.xlabel('Sold Coffee')
plt.ylabel('Temperature in Fahrenheit')
 #show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-ticks')
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]
plt.scatter(X,Y)
plt.xlim(0,1000)
plt.ylim(0,100)
#scatter plot color
plt.scatter(X, Y, s=60, c='red', marker='^')
#change axes ranges
plt.xlim(0,1000)
plt.ylim(0,100)
#add title
plt.title('Relationship Between Temperature and Iced Coffee Sales')
#add x and y labels
plt.xlabel('Sold Coffee')
plt.ylabel('Temperature in Fahrenheit')
#show plot
plt.show()
# Out:
# /tmp/ipykernel_4102/2057925041.py:4: MatplotlibDeprecationWarning:
#
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')
# Create empty figure
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
# set the x and y axis range
plt.xlim(0, 11)
plt.ylim(-2, 2)
plt.axis('tight')
#add title
plt.title('Plotting data using sin and cos')
# Out:
# /tmp/ipykernel_4102/2873481694.py:4: MatplotlibDeprecationWarning:
#
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
# Text(0.5, 1.0, 'Plotting data using sin and cos')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('classic')
plt.style.use('seaborn-whitegrid')
# Create some data for further exploration check out https://numpy.org/doc/stable/reference/random/generated/numpy.random.multivariate_normal.html
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]],
size=2000)# [0, 0] is mean and [[5, 2], [2, 2]] is covariance which you will learn about later!
data = pd.DataFrame(data, columns=['x', 'y'])

print(data)
# Plot the data with seaborn
sns.distplot(data['x'])
sns.distplot(data['y']);
# Out:
# /tmp/ipykernel_4102/3087440374.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# /tmp/ipykernel_4102/3087440374.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['x'])
#              x         y
# 0    -3.466172 -4.134653
# 1    -5.524980 -1.598674
# 2     3.736968  2.255193
# 3     0.459206  0.276846
# 4    -1.172077 -0.856105
# ...        ...       ...
# 1995  2.162337  2.110080
# 1996  1.612122  1.243811
# 1997 -2.317381 -2.332162
# 1998  1.255357 -0.521839
# 1999  1.340484  1.658754
#
# [2000 rows x 2 columns]
# /tmp/ipykernel_4102/3087440374.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['y']);

# %%
for col in 'xy':   #x and y the columens defined above
    sns.kdeplot(data[col], shade=True)
# Out:
# /tmp/ipykernel_4102/3937169544.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# /tmp/ipykernel_4102/3937169544.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
with sns.axes_style('white'):
     sns.jointplot("x", "y", data, kind='kde');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 with sns.axes_style('white'):
# ----> 2      sns.jointplot("x", "y", data, kind='kde')
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
import seaborn as sns
with sns.axes_style('white'):
     sns.jointplot("x", "y", data, kind='hex')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 import seaborn as sns
#       2 with sns.axes_style('white'):
# ----> 3      sns.jointplot("x", "y", data, kind='hex')
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
sns.pairplot(data);

# %%
# YOU CAN REMOVE JUST THE SINGLE # STARTING FROM HERE!

##from chart_studio.plotly import plot, iplot  ## for online use

from plotly.offline import iplot ## for offline use

import plotly.graph_objs as go
import numpy as np
x = np.random.randn(200)
y = np.random.randn(200)
iplot([go.Histogram2dContour(x=x, y=y,
contours=dict (coloring='heatmap')),
go.Scatter(x=x, y=y, mode='markers',
marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div>                            <div id="8470d964-03b7-4961-9144-f987186a3925" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8470d964-03b7-4961-9144-f987186a3925")) {                    Plotly.newPlot(                        "8470d964-03b7-4961-9144-f987186a3925",                        [{"contours":{"coloring":"heatmap"},"x":[-0.6440420620125469,1.0378040020960646,0.5154782942859777,-1.7370743101434385,0.33720267554038896,1.6484235752044765,0.07860233736177906,1.45865064055673,-0.4238541636903863,-0.4546320996659642,-2.1503620396423475,-0.3429604081255826,0.5233749222557361,0.00809198952051361,1.1116052687869424,-0.6662187304866649,-1.8309969394847647,0.22247210830646708,-0.7954774333800696,-0.6903632494129512,-3.020592930077689,-1.2186629647180383,-0.3886314756268223,0.49587748152220074,-0.4046019364586505,-1.8084651766442033,0.5389030033412209,-0.7205696746393528,-0.22798969172932135,0.2247828596228275,-0.4422809115765318,-0.1401741680675401,-0.12354059468324324,-1.6189547538831104,0.913798783532283,-0.27605807206342425,0.97636469267268,-0.24898958456451584,-0.6675364618859753,-0.11211184413916915,0.7790998907440041,-1.348520772098538,1.4138193845532139,-0.22195180544594575,0.5403673643170419,0.25197175372583264,-2.355496594234531,-0.380197103491272,0.06794972367048846,1.3992884311369143,-0.6682862670123746,-1.3207707051088657,0.22708963593186238,0.5180220252963194,-0.627876330939744,-0.13228535501594593,-1.9693643978255573,-0.7183781978636814,-1.6150711851855009,-1.5924361507783573,1.6952231723014357,-0.5531038562253747,-0.2526412755082508,-0.5292895372288302,-0.2582975160492418,0.3507488747556496,-0.9154351079531463,-0.3422746671334751,-0.02352073675837806,-1.0264380719917279,-1.125789409266611,-0.7160628204958173,0.07456465886043326,-1.5486664416711506,-1.080266642470547,0.26590396989125686,0.47175067646800156,-0.96820068670279,0.0491600708932852,0.7666994188904099,0.3405324790778489,2.699327177919767,0.8848911553836205,1.8441295787832304,1.5092472871821538,0.6659178437120495,0.2797353274839005,0.5467579370026595,0.6319401154376232,-0.6510760292968991,0.22282951384853206,-0.5185584455217648,1.95131797005123,0.9485598608114244,1.1095455524783042,-0.3795050840236072,1.887612211625967,-0.2382296709477784,1.5183932257729325,-1.6273000130800885,-1.273279003048708,1.4465399234152176,-0.3990406319547681,0.8882524496948084,2.034671318084766,0.48769004510270914,0.358437410748276,-0.6210371714071847,1.2617827934892567,-0.43274827789677095,0.16865273733926858,-1.2728484118684769,-0.46799337001228425,-0.8677092153075331,0.5390800053726332,-1.470667785232023,0.20022818128974945,0.4580400196349874,1.6054280193929569,-1.979572664862532,-0.17626492890952458,0.07358783804088408,-0.947312276529427,2.3311511761304464,-1.1167875582551618,-0.5953490855505025,0.5484836292741254,-0.48871933557250874,-0.24046760828382888,0.807604459268428,-0.5640354058969335,0.08596534104449563,1.9550007236093951,1.9471418123504178,-0.8408252771044563,0.1401530368392283,-0.43686468348863794,0.3097253779408828,-0.23673025508360102,0.08344429074474288,-0.03242002190358839,-0.4290926976518047,1.0968977486365183,0.30453714337751747,-0.023834914748655386,-1.1613550141714108,-0.4280066510684825,-0.0756339887099519,0.8229363238775189,1.3814557812585826,0.6796110380297146,-1.369774458721997,0.40521584125742033,-0.5791368989064883,-0.09887144624178835,-1.3461376886186636,0.08597506979338937,-0.2127185077899043,0.7922655669425713,1.1482484761997411,1.170077414580111,1.686770353255706,1.630335851982985,-0.055757503755481774,-0.8121577495723649,1.311194184164129,-1.8345904618232711,-0.768594195948646,-0.19224025884821774,-0.6203807155057778,0.2547149730404149,1.1254225560533007,1.4698147092770477,-0.6056185795959645,0.7977835478987776, ...

# %% [markdown]
# ## Use plotly.offline to execute the Plotly script offline within a notebook as shown below:

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30, 44]}], 'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# 'temp-plot.html'

# %%
# pip install pylot

# %% [markdown]
# ## Executing the Plotly Python script, as shown in the code block below, will open a web browser with the dynamic Plotly graph drawn, as shown in figure generated below:

# %%
#from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
#init_notebook_mode(connected=True)
#print (__version__)

# %%
# import plotly.graph_objs as go

# %%
#plot([go.Scatter(x=[95, 77, 84], y=[75, 67, 56])])

# %% [markdown]
# #### Note: we were commenting the above lines to be able to easly save the whole chapter as a lecture note in pdf, when you run the code remove the '\#'

# %% [markdown]
# # Geoplotlib

# %% [markdown]
# Geoplotlib is a toolbox for creating a variety of map types and plotting
# geographical data. Geoplotlib needs Pyglet as an object-oriented
# programming interface. We will cover this around the end of the course if time allows.

# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a Python library written for data manipulation and analysis.
# You can use Python with Pandas in a variety of academic and commercial
# domains, including finance, economics, statistics, advertising, web
# analytics, and much more.

# %%
# Few Examples
# you will learn about pandas data frame "pd.DataFrame" in the 5th Chapter!
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(100,6),index= pd.date_range('1/9/2022', periods=100), columns= list('ABCDEF'))
df.plot(figsize=(20, 10)).legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ### Direct Ploting

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb',
'March','April', 'May'])
df
df.plot.bar(figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# ### Create a stacked bar plot

# %% [markdown]
# #### Here you need to just add one more argument stacked=True as shown below:

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb',
'March','April', 'May'])
df.plot.bar(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# ### Create a horizontal stacked bar plot

# %% [markdown]
# #### Here you need to just need to change one argument df.plot.bar into  df.plot.barh as shown below:

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb',
'March','April', 'May'])
df.plot.barh(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# ## <font size = '6' color='red'> Home Work No. 2 [20 points] <font>

# %% [markdown]
# # Produce similar visualization as in the above given ones by taking some data sets related to Kyrgyzstan. Consider applying at least line charts, bar charts, stacked bar charts, histograms, pie charts and violin plots.
